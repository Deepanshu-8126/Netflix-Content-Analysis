# %%
import numpy as np 
import pandas as pd 
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
print(df.shape)
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# missing values analysis 
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
#   movie vs tv shows  
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
df['country'].value_counts().head(10)
# Out:
# country
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: count, dtype: int64

# %%
# top ratings 
rating = df['rating'].value_counts()

# %%
# top directors 
df['director'].value_counts().head(10)
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
# release year trend
df['release_year'].value_counts().sort_index()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1032
# 2018    1147
# 2019    1030
# 2020     953
# 2021     592
# Name: count, Length: 74, dtype: int64

# %%
import matplotlib.pyplot as plt 
df['type'].value_counts().plot(kind='bar')
plt.title("Movies vs Tv shows ")
plt.xlabel("Content Type")
plt.ylabel("Count")
plt.show()

# %%
top_countries = df['country'].value_counts().head(10)
top_countries.plot(kind='bar')
plt.ylabel('Top 10 Country Producing Countries ')
plt.xlabel('Country')
plt.show()

# %%
rating.plot(kind='bar')
plt.xlabel("Rating")
plt.ylabel("Number of Titles")
plt.show()

# %%
# release year trend analysis
year_trend = df['release_year'].value_counts().sort_index()
year_trend.plot(kind='line')
plt.title('Netflix content release trend ')
plt.xlabel('Release Year ')
plt.ylabel('Number of Trends ')
plt.show()

# %%
# Genre analysis ( content type ) 
genre = df['listed_in'].value_counts().head(10)
genre
genre.plot(kind='bar')
plt.title('Top 10 Genres on Netflix')
plt.xlabel('Genre')
plt.ylabel('Number of Titles')

plt.show()

# %%
topdirectors = df['director'].value_counts().head(10)


topdirectors.plot(kind='bar')

plt.title('Top 10 Directors on Netflix')
plt.xlabel('Director')
plt.ylabel('Number of Titles')

plt.show()

# %% [markdown]
# Rajiv Chilaka is the most frequent director in the dataset with 19 titles, followed by Raul Campos and Jan Suter.

# %%
# movies andd tv shows overall trend 
mv_trend = pd.crosstab(df['release_year'], df['type'])
mv_trend.plot(figsize=(12,6))
plt.title('Movies vs TV Shows Trend Over Time')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.show()

# %%
country_type = pd.crosstab(
    df['country'],df['type']
)

country_type.sort_values(
    by='Movie',
    ascending=False
).head(10).plot(
    kind='bar',
    figsize=(12,6)
)


plt.title('Top Countries Content Mix')
plt.show()

# %%
df['decade'] = (df['release_year']//10)*10

df['decade'].value_counts().sort_index().plot(kind='bar')
plt.title('Content by Decade')
plt.show()

# %%
yearly = (
    df['release_year']
    .value_counts()
    .sort_index()
)

growth = yearly.pct_change()*100
growth.tail(15)
growth.plot(figsize=(12,6))
plt.title('Year-over-Year Content Growth %')

plt.show()

# %% [markdown]
# Netflix contains significantly more Movies (6,131) than TV Shows (2,676).
#
# The United States is the largest contributor to Netflix content.
#
# India is the second-largest content-producing country in the dataset.
#
# TV-MA and TV-14 are the most common content ratings on Netflix.
#
# Content releases increased significantly after 2015, indicating rapid platform growth.
#
# Rajiv Chilaka is the most frequent director in the dataset with 19 titles.
#
# The average release year is 2014, showing that the catalog is heavily focused on recent content.
#
# International Movies, Dramas, and Comedies are among the most dominant genres.
# Content production is concentrated in a few major countries rather than being evenly distributed worldwide.
#
# Most movies fall within a standard feature-length duration range.
# Netflix experienced substantial content expansion during the late 2010s.
#
# Movie content dominates the platform across most top-producing countries.
#
# The dataset contains no duplicate records, ensuring reliable analysis.
# Director information has the highest number of missing values among all columns.
# Recent decades contribute the majority of titles available in the Netflix catalog.
